# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.loadtxt('hist.csv')

# %%
plt.hist(data,bins=100)
plt.title('Pair Indexes')
plt.xlabel('indexes')
plt.ylabel('number')
plt.show()
